# %%
def text():
     f1 = open('/Users/jindie/Desktop/video_t/v_t_good.txt','r',encoding='utf-8') 
     f2 = open('/Users/jindie/Desktop/video_t/v_t_bad.txt','r',encoding='utf-8')
     line1 = f1.readline()
     line2 = f2.readline()
     str = ''
     while line1:
         str += line1
         line1 = f1.readline()
     while line2:
         str += line2
         line2 = f2.readline()
     f1.close()
     f2.close()
     return str

def bag_of_words(words):
     return dict([(word,True) for word in words])

print(bag_of_words(text()))
# Out:
# {'3': True, '"': True, ':': True, '确': True, '实': True, ',': True, '\n': True, '8': True, '很': True, '多': True, '体': True, '育': True, '运': True, '动': True, '没': True, '有': True, '亲': True, '身': True, '参': True, '与': True, '会': True, '不': True, '到': True, '的': True, '，': True, '而': True, '年': True, '轻': True, '一': True, '辈': True, '明': True, '显': True, '对': True, '电': True, '竞': True, '更': True, '感': True, '兴': True, '趣': True, '9': True, '和': True, '奢': True, '侈': True, '品': True, '牌': True, '请': True, '网': True, '红': True, '走': True, '秀': True, '个': True, '道': True, '理': True, '抓': True, '住': True, '代': True, '、': True, '1': True, '你': True, '爱': True, '认': True, '说': True, '了': True, '也': True, '算': True, '2': True, '商': True, '业': True, '版': True, '图': True, 'I': True, 'E': True, 'S': True, 'F': True, ' ': True, '主': True, '办': True, '话': True, '腾': True, '讯': True, '加': True, '入': True, '0': True, '暴': True, '雪': True, '除': True, '外': True, '梦': True, '三': True, '国': True, '钱': True, '啊': True, '原': True, '神': True, '启': True, '。': True, '6': True, '我': True, '去': True, '！': True, '同': True, '学': True, '就': True, '是': True, '仁': True, '川': True, '人': True, '7': True, '这': True, '游': True, '戏': True, '好': True, '厉': True, '害': True, '爸': True, '儿': True, '子': True, '都': True, '拿': True, '冠': True, '军': True, '呢': True, '扯': True, '淡': True, '要': True, '知': True, '些': True, '选': True, '手': True, '训': True, '练': True, '程': True, '度': True, '比': True, '别': True, '项': True, '目': True, '少': True, '需': True, '长': True, '时': True, '间': True, '集': True, '中': True, '注': True, '意': True, '力': True, '求': True, '每': True, '天': True, '五': True, '公': True, '里': True, '锻': True, '炼': True, '质': True, '志': True, '无': True, '论': True, '可': True, '他': True, '当': True, '之': True, '愧': True, '足': True, '球': True, '水': True, '平': True, '最': True, '高': True, '欧': True, '收': True, '视': True, '世': True, '界': True, '杯': True, '4': True, '呗': True, '虽': True, '然': True, '打': True, '但': True, '挺': True, '舞': True, '全': True, '开': True, '（': True, '刀': True, '塔': True, '5': True, '登': True, '录': True, '奇': True, '艺': True, '霍': True, '刚': True, '还': True, '越': True, '受': True, '众': True, '组': True, '织': True, '者': True, '才': True, '语': True, '权': True, '进': True, '获': True, '得': True, '利': True, '益': True, '在': True, '种': True, '趋': True, '势': True, '下': True, '想': True, '圈': True, '地': True, '自': True, '萌': True, '能': True, '接': True, '来': True, '美': True, '洲': True, '抢': True, '流': True, '量': True, '补': True, '丁': True, '规': True, '则': True, '早': True, '晚': True, '成': True, '为': True, '奥': True, '热': True, '门': True, '啥': True, '键': True, '盘': True, '希': True, '望': True, '独': True, '立': True, '赛': True, '事': True, '举': True, '亚': True, '盛': True, '宴': True, '传': True, '统': True, '反': True, '倒': True, '群': True, '等': True, '慢': True, '被': True, '看': True, '玩': True, '技': True, '专': True, '花': True, '鸟': True, '风': True, '月': True, '哈': True, '新': True, '鲜': True, '血': True, '液': True, '捏': True, '耶': True, '雅': True, '达': True, '怎': True, '么': True, '哦': True, '豁': True, '吸': True, '引': True, '已': True, '经': True, '快': True, '表': True, '演': True, '正': True, '式': True, '如': True, '果': True, '总': True, '前': True, '吧': True, '？': True, '那': True, '候': True, '各': True, '条': True, '件': True, '熟': True, '英': True, '雄': True, '联': True, '盟': True, '应': True, '该': True, '弄': True, '现': True, '零': True, '后': True, '络': True, '又': True, '行': True, '以': True, '心': True, '乐': True, '废': True, '寝': True, '忘': True, '食': True, '谁': True, '关': True, '什': True, '觉': True, '真': True, '境': True, '角': True, '否': True, '大': True, '化': True, '特': True, '性': True, 'b': True, 'u': True, 'g': True, '概': True, '率': True, '因': True, '素': True, '评': True, '定': True, '消': True, '息': True, '篮': True, '样': True, '出': True, '路': True, '哟': True, '攀': True, '岩': True, '男': True, '生': True, '女': True, '向': True, '冲': True, 'G': True, 'O': True, 'A': True, 'T': True, '本': True, '盖':  ...

# %%
import nltk
from nltk.collocations import  BigramCollocationFinder
from nltk.metrics import  BigramAssocMeasures

def  bigram(words,score_fn=BigramAssocMeasures.chi_sq,n=1000):
     bigram_finder=BigramCollocationFinder.from_words(words)  #把文本变成双词搭配的形式
     bigrams = bigram_finder.nbest(score_fn,n)  #使用卡方统计的方法，选择排名前1000的双词
     newBigrams = [u+v for (u,v) in bigrams]
     return bag_of_words(newBigrams)
     
print(bigram(text(),score_fn=BigramAssocMeasures.chi_sq,n=1000))
# Out:
# {'して': True, 'よう': True, 'クホ': True, 'ック': True, 'ブラ': True, 'ホー': True, 'ラッ': True, 'ルは': True, 'ール': True, '介绍': True, '傷し': True, '凌晨': True, '凝聚': True, '刹碧': True, '卧槽': True, '召唤': True, '哽咽': True, '喂給': True, '埋怨': True, '奢侈': True, '奧運': True, '奶茶': True, '娘炮': True, '嬴政': True, '孙膑': True, '峡谷': True, '峻娘': True, '建议': True, '惹嗮': True, '扩*': True, '扭腰': True, '拘谨': True, '撒谎': True, '旮旯': True, '杉矶': True, '標準': True, '泰坦': True, '洗澡': True, '涤纶': True, '淘汰': True, '渺茫': True, '烘焙': True, '父母': True, '玫瑰': True, '玻璃': True, '田忌': True, '疙瘩': True, '盈眶': True, '碰瓷': True, '禁锢': True, '窝巢': True, '缭绕': True, '羡慕': True, '肠寸': True, '腐蚀': True, '腱鞘': True, '葡萄': True, '蚌埠': True, '蚴蛔': True, '蝌蚪': True, '裹挟': True, '贡献': True, '辉煌': True, '込み': True, '逻辑': True, '遊戲': True, '遮羞': True, '酬勤': True, '采访': True, '锻炼': True, '雀跃': True, '雾缭': True, '鞘炎': True, '鞭尸': True, '颈椎': True, '骆歆': True, '游戏': True, '荣耀': True, '巅峰': True, '影响': True, '乒乓': True, '污渍': True, '荒谬': True, '世界': True, '\\/': True, '喵斯': True, '杭州': True, '腾讯': True, '仁川': True, '恐怖': True, '摆烂': True, '沉迷': True, '弹幕': True, '盖伦': True, '喝酒': True, '幽默': True, '联盟': True, '王者': True, '策划': True, '厉害': True, '皮肤': True, '广告': True, '排面': True, '贴膜': True, '嘻嘻': True, '卸载': True, '圣召': True, '垃圾': True, '尼玛': True, '扯淡': True, '抄袭': True, '枯燥': True, '温馨': True, '渲染': True, '答辩': True, '详细': True, '稍微': True, '兴趣': True, '希望': True, '哈哈': True, '青春': True, '奇艺': True, '螺丝': True, '冠军': True, '普通': True, '传统': True, '体育': True, '乌兹': True, '樵夫': True, '硕士': True, '容易': True, '研究': True, '英雄': True, '电竞': True, '牛逼': True, 'RN': True, '春饭': True, '刻板': True, '已经': True, '健康': True, '甚至': True, '坚持': True, '项目': True, '板印': True, '暴雪': True, '键盘': True, '残酷': True, '应该': True, '魔兽': True, '什么': True, '自己': True, '姿态': True, '规则': True, '离谱': True, '˙︶': True, '」∠': True, 'いる': True, 'い込': True, 'たち': True, 'ちの': True, 'てい': True, 'のよ': True, 'のブ': True, 'をあ': True, '侮辱': True, '冬暖': True, '冬瓜': True, '刘翔': True, '古董': True, '土壤': True, '奔赴': True, '崩溃': True, '戲離': True, '抱歉': True, '拓宽': True, '攀岩': True, '暑假': True, '滑轨': True, '满贯': True, '漂亮': True, '漏姓': True, '炸聋': True, '烦恼': True, '燥乏': True, '耻辱': True, '藏私': True, '藤井': True, '蛔隐': True, '透漏': True, '遗憾': True, '避免': True, '風を': True, '︶˙': True, 'ᴗ❛': True, '❛ᴗ': True, '即使': True, '固执': True, '洛杉': True, '贷款': True, '露娜': True, '兄弟': True, '炉石': True, '鸦片': True, '鬼泣': True, '麻将': True, '领先': True, '工作': True, '知道': True, '搓玻': True, '硬币': True, '印象': True, '伎俩': True, '震惊': True, '依旧': True, '培养': True, '雄联': True, '卡萨': True, '嗷嗷': True, '肌肉': True, '喜欢': True, 'NG': True, '街霸': True, '深圳': True, '遥领': True, '任何': True, '贵妇': True, '确实': True, '冷静': True, '厨狂': True, '夸张': True, '骄傲': True, '企鹅': True, '抽烟': True, '熬夜': True, '优势': True, '克烈': True, '网瘾': True, '组织': True, '围棋': True, '辛苦': True, '者荣': True, '永远': True, '央视': True, '随便': True, '利益': True, '..': True, '天赋': True, '[杨': True, 'あな': True, 'うな': True, 'さな': True, 'な黒': True, '俘虏': True, '党摆': True, '凤凰': True, '呼雀': True, '壁江': True, '尸炉': True, '尽皆': True, '庆祝': True, '慈善': True, '搜索': True, '楚钧': True, '瓦兰': True, '祝贺': True, '空莹': True, '羞布': True, '耽误': True, '肝肠': True, '艾滋': True, '茅厕': True, '贫困': True, '钓鱼': True, '隔壁': True, '食粮': True, '副编': True, '隆石': True, '修仙': True, '削宫': True, '虚拟': True, '贫富': True, '程序': True, '继续': True, '读书': True, '东西': True, '扫雷': True, '侠盗': True, '职业': True, '戒网': True, '奥运': True, '肯定': True, '门槛': True, '原神': True, '叮～': True, '背景': True, '香锅': True, '恭喜': True, '碾压': True, '篮球': True, '偏见': True, '因为': True, '条件': True, '七圣': True, '侈品': True, '唐丹': True, '查狄': True, '朋友': True, '爱奇': True, '猫雷': True, '农药': True, '垄断': True, '熟悉': True, '皇室': True, '浪费': True, '泪目': True, '如果': True, 'ta': True, '估计': True, '波澜': True, '监狱': True, '访苏': True, '消遣': True, '结束': True, '退役': True, '老师': True, '刀塔': True, 'ng': True, '现在': True, '*器': True, 'JK': True, '乏味': True, '具备': True, '勿喷': True, '奋 ...

# %%
def  bigram_words(words,score_fn=BigramAssocMeasures.chi_sq,n=1000):
     bigram_finder=BigramCollocationFinder.from_words(words)
     bigrams = bigram_finder.nbest(score_fn,n)
     newBigrams = [u+v for (u,v) in bigrams]
     a = bag_of_words(words)
     b = bag_of_words(newBigrams)
     a.update(b)  #把字典b合并到字典a中
     return a 

print(bigram_words(text(),score_fn=BigramAssocMeasures.chi_sq,n=1000))
# Out:
# {'3': True, '"': True, ':': True, '确': True, '实': True, ',': True, '\n': True, '8': True, '很': True, '多': True, '体': True, '育': True, '运': True, '动': True, '没': True, '有': True, '亲': True, '身': True, '参': True, '与': True, '会': True, '不': True, '到': True, '的': True, '，': True, '而': True, '年': True, '轻': True, '一': True, '辈': True, '明': True, '显': True, '对': True, '电': True, '竞': True, '更': True, '感': True, '兴': True, '趣': True, '9': True, '和': True, '奢': True, '侈': True, '品': True, '牌': True, '请': True, '网': True, '红': True, '走': True, '秀': True, '个': True, '道': True, '理': True, '抓': True, '住': True, '代': True, '、': True, '1': True, '你': True, '爱': True, '认': True, '说': True, '了': True, '也': True, '算': True, '2': True, '商': True, '业': True, '版': True, '图': True, 'I': True, 'E': True, 'S': True, 'F': True, ' ': True, '主': True, '办': True, '话': True, '腾': True, '讯': True, '加': True, '入': True, '0': True, '暴': True, '雪': True, '除': True, '外': True, '梦': True, '三': True, '国': True, '钱': True, '啊': True, '原': True, '神': True, '启': True, '。': True, '6': True, '我': True, '去': True, '！': True, '同': True, '学': True, '就': True, '是': True, '仁': True, '川': True, '人': True, '7': True, '这': True, '游': True, '戏': True, '好': True, '厉': True, '害': True, '爸': True, '儿': True, '子': True, '都': True, '拿': True, '冠': True, '军': True, '呢': True, '扯': True, '淡': True, '要': True, '知': True, '些': True, '选': True, '手': True, '训': True, '练': True, '程': True, '度': True, '比': True, '别': True, '项': True, '目': True, '少': True, '需': True, '长': True, '时': True, '间': True, '集': True, '中': True, '注': True, '意': True, '力': True, '求': True, '每': True, '天': True, '五': True, '公': True, '里': True, '锻': True, '炼': True, '质': True, '志': True, '无': True, '论': True, '可': True, '他': True, '当': True, '之': True, '愧': True, '足': True, '球': True, '水': True, '平': True, '最': True, '高': True, '欧': True, '收': True, '视': True, '世': True, '界': True, '杯': True, '4': True, '呗': True, '虽': True, '然': True, '打': True, '但': True, '挺': True, '舞': True, '全': True, '开': True, '（': True, '刀': True, '塔': True, '5': True, '登': True, '录': True, '奇': True, '艺': True, '霍': True, '刚': True, '还': True, '越': True, '受': True, '众': True, '组': True, '织': True, '者': True, '才': True, '语': True, '权': True, '进': True, '获': True, '得': True, '利': True, '益': True, '在': True, '种': True, '趋': True, '势': True, '下': True, '想': True, '圈': True, '地': True, '自': True, '萌': True, '能': True, '接': True, '来': True, '美': True, '洲': True, '抢': True, '流': True, '量': True, '补': True, '丁': True, '规': True, '则': True, '早': True, '晚': True, '成': True, '为': True, '奥': True, '热': True, '门': True, '啥': True, '键': True, '盘': True, '希': True, '望': True, '独': True, '立': True, '赛': True, '事': True, '举': True, '亚': True, '盛': True, '宴': True, '传': True, '统': True, '反': True, '倒': True, '群': True, '等': True, '慢': True, '被': True, '看': True, '玩': True, '技': True, '专': True, '花': True, '鸟': True, '风': True, '月': True, '哈': True, '新': True, '鲜': True, '血': True, '液': True, '捏': True, '耶': True, '雅': True, '达': True, '怎': True, '么': True, '哦': True, '豁': True, '吸': True, '引': True, '已': True, '经': True, '快': True, '表': True, '演': True, '正': True, '式': True, '如': True, '果': True, '总': True, '前': True, '吧': True, '？': True, '那': True, '候': True, '各': True, '条': True, '件': True, '熟': True, '英': True, '雄': True, '联': True, '盟': True, '应': True, '该': True, '弄': True, '现': True, '零': True, '后': True, '络': True, '又': True, '行': True, '以': True, '心': True, '乐': True, '废': True, '寝': True, '忘': True, '食': True, '谁': True, '关': True, '什': True, '觉': True, '真': True, '境': True, '角': True, '否': True, '大': True, '化': True, '特': True, '性': True, 'b': True, 'u': True, 'g': True, '概': True, '率': True, '因': True, '素': True, '评': True, '定': True, '消': True, '息': True, '篮': True, '样': True, '出': True, '路': True, '哟': True, '攀': True, '岩': True, '男': True, '生': True, '女': True, '向': True, '冲': True, 'G': True, 'O': True, 'A': True, 'T': True, '本': True, '盖':  ...

# %%
import jieba

def read_file(filename):
     stop = [line.strip() for line in  open('/Users/jindie/Desktop/video_t/hit_stopwords_vt.txt','r',encoding='utf-8').readlines()]  #停用词
     f = open(filename,'r',encoding='utf-8')
     line = f.readline()
     str = []
     while line:
         s = line.split('\t')
         fenci = jieba.cut(s[0],cut_all=False)  #False默认值：精准模式
         str.append(list(set(fenci)-set(stop)))
         line = f.readline()
     return str

# %%
from nltk.probability import  FreqDist,ConditionalFreqDist
from nltk.metrics import  BigramAssocMeasures

def jieba_feature(number):   
     posWords = []
     negWords = []
     for items in read_file('/Users/jindie/Desktop/video_t/v_t_good.txt'):#把集合的集合变成集合
         for item in items:
            posWords.append(item)
     for items in read_file('/Users/jindie/Desktop/video_t/v_t_bad.txt'):
         for item in items:
            negWords.append(item)
  
     word_fd = FreqDist() #可统计所有词的词频
     cond_word_fd = ConditionalFreqDist() #可统计积极文本中的词频和消极文本中的词频
  
     for word in posWords:
         word_fd[word] += 1
         cond_word_fd['pos'][word] += 1
  
     for word in negWords:
         word_fd[word] += 1
         cond_word_fd['neg'][word] += 1
  
     pos_word_count = cond_word_fd['pos'].N() #积极词的数量
     neg_word_count = cond_word_fd['neg'].N() #消极词的数量
     total_word_count = pos_word_count + neg_word_count
  
     word_scores = {}#包括了每个词和这个词的信息量
  
     for word, freq in word_fd.items():
         pos_score = BigramAssocMeasures.chi_sq(cond_word_fd['pos'][word],  (freq, pos_word_count), total_word_count) #计算积极词的卡方统计量，这里也可以计算互信息等其它统计量
         neg_score = BigramAssocMeasures.chi_sq(cond_word_fd['neg'][word],  (freq, neg_word_count), total_word_count) 
         word_scores[word] = pos_score + neg_score #一个词的信息量等于积极卡方统计量加上消极卡方统计量
  
     best_vals = sorted(word_scores.items(), key=lambda item:item[1],  reverse=True)[:number] #把词按信息量倒序排序。number是特征的维度，是可以不断调整直至最优的
     best_words = set([w for w,s in best_vals])
     return dict([(word, True) for word in best_words])

def build_features():
     #feature = bag_of_words(text())#第一种：单个词
     #feature = bigram(text(),score_fn=BigramAssocMeasures.chi_sq,n=500)#第二种：双词
     #feature =  bigram_words(text(),score_fn=BigramAssocMeasures.chi_sq,n=500)#第三种：单个词和双个词
     feature = jieba_feature(300)#第四种：结巴分词
  
     posFeatures = []
     for items in read_file('/Users/jindie/Desktop/video_t/v_t_good.txt'):
         a = {}
         for item in items:
            if item in feature.keys():
                a[item]='True'
         posWords = [a,'pos'] #为积极文本赋予"pos"
         posFeatures.append(posWords)
     negFeatures = []
     for items in read_file('/Users/jindie/Desktop/video_t/v_t_bad.txt'):
         a = {}
         for item in items:
            if item in feature.keys():
                a[item]='True'
         negWords = [a,'neg'] #为消极文本赋予"neg"
         negFeatures.append(negWords)
     return posFeatures,negFeatures

# %%
posFeatures,negFeatures =  build_features()

from random import shuffle
shuffle(posFeatures) 
shuffle(negFeatures) #把文本的排列随机化  
train =  posFeatures[300:]+negFeatures[300:]#训练集(70%)
test = posFeatures[:300]+negFeatures[:300]#验证集(30%)
data,tag = zip(*test)#分离测试集合的数据和标签，便于验证和测试

def score(classifier):
     classifier = SklearnClassifier(classifier) 
     classifier.train(train) #训练分类器
     pred = classifier.classify_many(data) #给出预测的标签
     n = 0
     s = len(pred)
     for i in range(0,s):
         if pred[i]==tag[i]:
            n = n+1
     return n/s #分类器准确度

import sklearn
from nltk.classify.scikitlearn import  SklearnClassifier
from sklearn.svm import SVC, LinearSVC,  NuSVC
from sklearn.naive_bayes import  MultinomialNB, BernoulliNB
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import  accuracy_score

print('BernoulliNB`s accuracy is %f'  %score(BernoulliNB()))
print('MultinomiaNB`s accuracy is %f'  %score(MultinomialNB()))
print('LogisticRegression`s accuracy is  %f' %score(LogisticRegression()))
print('SVC`s accuracy is %f'  %score(SVC()))
print('LinearSVC`s accuracy is %f'  %score(LinearSVC()))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/sj/13zrkmpd1zsbqqc006p8wmdw0000gn/T/jieba.cache
# Loading model cost 0.329 seconds.
# Prefix dict has been built successfully.
# BernoulliNB`s accuracy is 0.725000
# MultinomiaNB`s accuracy is 0.725000
# LogisticRegression`s accuracy is  0.700000
# SVC`s accuracy is 0.688333
# LinearSVC`s accuracy is 0.715000
# /Users/jindie/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
