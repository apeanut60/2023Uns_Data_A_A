# %%
def text():
     f1 = open('/Users/jindie/Desktop/video_2/v2_good.txt','r',encoding='utf-8') 
     f2 = open('/Users/jindie/Desktop/video_2/v2_bad.txt','r',encoding='utf-8')
     line1 = f1.readline()
     line2 = f2.readline()
     str = ''
     while line1:
         str += line1
         line1 = f1.readline()
     while line2:
         str += line2
         line2 = f2.readline()
     f1.close()
     f2.close()
     return str

def bag_of_words(words):
     return dict([(word,True) for word in words])

print(bag_of_words(text()))
# Out:
# {'2': True, '"': True, ':': True, '1': True, '4': True, '岁': True, '巅': True, '峰': True, '前': True, '0': True, '，': True, '这': True, '个': True, '实': True, '力': True, '已': True, '经': True, '能': True, '够': True, '到': True, '青': True, '训': True, '的': True, '门': True, '槛': True, '了': True, ',': True, '\n': True, '知': True, '道': True, '啊': True, '什': True, '么': True, '克': True, '隆': True, '石': True, '啦': True, '樵': True, '夫': True, '球': True, 'd': True, 'o': True, 'g': True, 'e': True, '7': True, '两': True, '年': True, '半': True, '？': True, '（': True, '警': True, '觉': True, '）': True, '9': True, '垃': True, '红': True, '桑': True, '幻': True, '视': True, '体': True, '系': True, '：': True, '三': True, '冲': True, '羊': True, '典': True, '冰': True, '靠': True, '自': True, '己': True, '努': True, '赚': True, '钱': True, '！': True, '3': True, '说': True, '话': True, '真': True, '别': True, '酸': True, '叫': True, '天': True, '赋': True, '和': True, '家': True, '境': True, '一': True, '样': True, '都': True, '是': True, '上': True, '带': True, '来': True, '读': True, '书': True, '破': True, '万': True, '卷': True, '下': True, '笔': True, '如': True, '有': True, '神': True, '不': True, '弹': True, '幕': True, '在': True, '笑': True, '就': True, '学': True, '习': True, '你': True, '决': True, '定': True, '做': True, '要': True, '5': True, '我': True, '们': True, '友': True, '善': True, '点': True, '好': True, '吧': True, '…': True, '把': True, '谁': True, '生': True, '活': True, '铺': True, '开': True, '总': True, '找': True, '质': True, '疑': True, '理': True, '由': True, '朋': True, '6': True, '鬼': True, '泣': True, '瞩': True, '目': True, '劫': True, '期': True, '猛': True, '像': True, '战': True, ' ': True, '虎': True, '后': True, '还': True, '超': True, '级': True, '兵': True, '8': True, '行': True, '出': True, '状': True, '元': True, '啥': True, '面': True, '帅': True, '哥': True, 'C': True, 'R': True, '人': True, '坐': True, '住': True, '~': True, 'w': True, 'c': True, '口': True, '酒': True, '店': True, '怎': True, '熟': True, '悉': True, '他': True, '名': True, '刀': True, '司': True, '命': True, '多': True, '对': True, '同': True, '于': True, '偏': True, '见': True, '接': True, '受': True, '其': True, '挺': True, '小': True, '长': True, '苏': True, '打': True, '张': True, '科': True, '大': True, '佬': True, '脸': True, '无': True, '所': True, '谓': True, '吃': True, '完': True, '春': True, '饭': True, '再': True, '进': True, '厂': True, '也': True, '眼': True, 'J': True, 'K': True, '确': True, '才': True, '阿': True, '金': True, 'N': True, 'O': True, '解': True, '看': True, '吗': True, '何': True, '必': True, '贬': True, '低': True, '电': True, '竞': True, '选': True, '手': True, '久': True, '诚': True, '重': True, '高': True, '中': True, '班': True, '最': True, '居': True, '然': True, '择': True, '职': True, '业': True, '过': True, '纪': True, '单': True, '养': True, '邻': True, '干': True, '白': True, '丝': True, '少': True, '萝': True, '稳': True, '猫': True, '内': True, '肯': True, '牛': True, '逼': True, '屏': True, '黑': True, '双': True, '击': True, '试': True, '复': True, '旦': True, '清': True, '华': True, '专': True, '容': True, '易': True, '本': True, '毕': True, '工': True, '作': True, '现': True, '没': True, '得': True, '各': True, '亚': True, '运': True, '会': True, '代': True, '想': True, '跟': True, '念': True, '@': True, 'm': True, 'E': True, 'S': True, 'Y': True, '网': True, '握': True, '草': True, '姐': True, '太': True, '用': True, '更': True, '呢': True, '压': True, '声': True, '款': True, '校': True, '服': True, '孙': True, '膑': True, '秀': True, '梦': True, '老': True, '师': True, '注': True, '意': True, '叮': True, '～': True, '升': True, '准': True, '备': True, '德': True, '国': True, '修': True, '放': True, '弃': True, '处': True, '转': True, '折': True, '玩': True, '喵': True, '斯': True, '趣': True, '爱': True, '。': True, '坚': True, '持': True, '与': True, '退': True, '缩': True, '差': True, '去': True, '评': True, '判': True, '管': True, '只': True, '挣': True, '那': True, '悔': True, '羡': True, '慕': True, '游': True, '戏': True, '相': True, '通': True, '之': True, '黄': True, '孩': True, '子': True, '以': True, '当': True, '教': True, '练': True, '毛': True, '磊': True, '很':  ...

# %%
import nltk
from nltk.collocations import  BigramCollocationFinder
from nltk.metrics import  BigramAssocMeasures

def  bigram(words,score_fn=BigramAssocMeasures.chi_sq,n=1000):
     bigram_finder=BigramCollocationFinder.from_words(words)  #把文本变成双词搭配的形式
     bigrams = bigram_finder.nbest(score_fn,n)  #使用卡方统计的方法，选择排名前1000的双词
     newBigrams = [u+v for (u,v) in bigrams]
     return bag_of_words(newBigrams)
     
print(bigram(text(),score_fn=BigramAssocMeasures.chi_sq,n=1000))
# Out:
# {'()': True, 'JK': True, '介绍': True, '兄弟': True, '克隆': True, '卧槽': True, '即使': True, '召唤': True, '叮～': True, '哦孔': True, '喵斯': True, '围棋': True, '土壤': True, '圣召': True, '备德': True, '奶茶': True, '孔乙': True, '孙膑': True, '封闭': True, '尼玛': True, '峡谷': True, '巅峰': True, '左右': True, '幽默': True, '广告': True, '建议': True, '彩票': True, '影响': True, '扯淡': True, '挑细': True, '撒谎': True, '景音': True, '杀软': True, '棋含': True, '沉迷': True, '淘汰': True, '温馨': True, '烘焙': True, '父母': True, '玻璃': True, '畸形': True, '盲聋': True, '硕士': True, '禁锢': True, '福州': True, '稍微': True, '窝巢': True, '缭绕': True, '羡慕': True, '耽误': True, '肉记': True, '肌肉': True, '背景': True, '腾讯': True, '艾滋': True, '莹杯': True, '蚌埠': True, '蛟龙': True, '记忆': True, '调房': True, '貌取': True, '贡献': True, '踢足': True, '逻辑': True, '酬勤': True, '隔壁': True, '雾缭': True, '领域': True, '颈椎': True, '龙港': True, '游戏': True, '弹幕': True, '英雄': True, '刻板': True, '甚至': True, '荒谬': True, '荣耀': True, '电竞': True, '喜欢': True, '青春': True, '容易': True, '厉害': True, '猫雷': True, '策划': True, '摆烂': True, '联盟': True, '鬼泣': True, '王者': True, '喝酒': True, '坚持': True, '螺丝': True, '春饭': True, '研究': True, '兴趣': True, '恐怖': True, '波澜': True, '渲染': True, '环境': True, '监狱': True, '程序': True, '露娜': True, '刀司': True, '搓玻': True, '东西': True, '板印': True, '普通': True, '印象': True, '哈哈': True, '工作': True, '市场': True, '指甲': True, '樵夫': True, '瞩目': True, '自己': True, '原神': True, '视频': True, '离谱': True, '已经': True, '应该': True, '任何': True, '传统': True, '键盘': True, '什么': True, 'zi': True, '\\/': True, '_⊙': True, '⊙_': True, '世界': True, '产品': True, '依旧': True, '冬暖': True, '冬瓜': True, '冲羊': True, '利息': True, '坑货': True, '夜谭': True, '嫌疑': True, '巴掌': True, '恨终': True, '攻略': True, '枯燥': True, '楚钧': True, '残酷': True, '毛磊': True, '涯交': True, '烦恼': True, '私立': True, '空莹': True, '空调': True, '组织': True, '继续': True, '节奏': True, '贷款': True, '趋势': True, '遗恨': True, '遭罪': True, '钓鱼': True, '飞控': True, '骨枯': True, '周末': True, '复旦': True, '拉倒': True, '防沉': True, '隆石': True, '骄傲': True, '压声': True, '朋友': True, '牛逼': True, '深圳': True, '状元': True, '贫富': True, '～叮': True, '老师': True, '名刀': True, '网瘾': True, '顶尖': True, '垫底': True, '悲哀': True, '花顺': True, '足球': True, '风险': True, '馨提': True, '魔兽': True, '司命': True, '知道': True, '抽烟': True, '现在': True, '天赋': True, '偏见': True, '培养': True, '摇号': True, '随便': True, '符合': True, '..': True, '读书': True, '如果': True, 'PV': True, 'VP': True, '买彩': True, '俗称': True, '党摆': True, '冷静': True, '准备': True, '北漂': True, '否则': True, '品设': True, '套牢': True, '套阵': True, '宿舍': True, '寒窗': True, '寒颤': True, '将近': True, '帮助': True, '握草': True, '枪盲': True, '汽车': True, '滤镜': True, '甲盖': True, '盟峡': True, '缺陷': True, '脑壳': True, '设施': True, '谈恋': True, '贫困': True, '辨吸': True, '邻居': True, '锦标': True, '际项': True, '七圣': True, '宝锁': True, '宣传': True, '撤退': True, '贴膜': True, '退役': True, '退缩': True, '门槛': True, '保安': True, '设计': True, '谈收': True, '浪费': True, '混日': True, '代练': True, '确实': True, '成绩': True, '俱乐': True, '职业': True, '埠住': True, '理由': True, '寿命': True, 'CS': True, 'NB': True, '永远': True, '他们': True, 'Uz': True, '旦清': True, 'hh': True, '。。': True, '本科': True, '条件': True, '深渊': True, '知识': True, '努力': True, '因为': True, '提示': True, '眼镜': True, '战争': True, 'AG': True, '清华': True, '表性': True, '完全': True, '皇室': True, ';稍': True, 'TM': True, 'T^': True, '^T': True, '“帮': True, '“抛': True, '便宜': True, '保护': True, '卡美': True, '双击': True, '垃红': True, '垄断': True, '堆杀': True, '奇迹': True, '幸存': True, '弟姐': True, '弥补': True, '待遇': True, '恶语': True, '摇奶': True, '架乱': True, '激情': True, '炉石': True, '省流': True, '红桑': True, '织语': True, '美尔': True, '美股': True, '营销': True, '落伍': True, '衰落': True, '警察': True, '评判': True, '频(': True, '频故': True, '马离': True, '佼佼': True, '依据': True, '兽世': True, '冲突': True, '嘲讽': True, '夜厕': True, '妥妥': True, '滴滴': True, '邦邦': True, '阶层': True, '麻烦': True, '友善': True, '序员': True, '担心': True, '光明': True, '运营': True, '呃呃': True, '宝宝': True, '期猛': True, '肯定': True, '选择': True, '烟喝': True, '平等': True, '时间': True, '地方': True, '理解': True, '者 ...

# %%
def  bigram_words(words,score_fn=BigramAssocMeasures.chi_sq,n=1000):
     bigram_finder=BigramCollocationFinder.from_words(words)
     bigrams = bigram_finder.nbest(score_fn,n)
     newBigrams = [u+v for (u,v) in bigrams]
     a = bag_of_words(words)
     b = bag_of_words(newBigrams)
     a.update(b)  #把字典b合并到字典a中
     return a 

print(bigram_words(text(),score_fn=BigramAssocMeasures.chi_sq,n=1000))
# Out:
# {'2': True, '"': True, ':': True, '1': True, '4': True, '岁': True, '巅': True, '峰': True, '前': True, '0': True, '，': True, '这': True, '个': True, '实': True, '力': True, '已': True, '经': True, '能': True, '够': True, '到': True, '青': True, '训': True, '的': True, '门': True, '槛': True, '了': True, ',': True, '\n': True, '知': True, '道': True, '啊': True, '什': True, '么': True, '克': True, '隆': True, '石': True, '啦': True, '樵': True, '夫': True, '球': True, 'd': True, 'o': True, 'g': True, 'e': True, '7': True, '两': True, '年': True, '半': True, '？': True, '（': True, '警': True, '觉': True, '）': True, '9': True, '垃': True, '红': True, '桑': True, '幻': True, '视': True, '体': True, '系': True, '：': True, '三': True, '冲': True, '羊': True, '典': True, '冰': True, '靠': True, '自': True, '己': True, '努': True, '赚': True, '钱': True, '！': True, '3': True, '说': True, '话': True, '真': True, '别': True, '酸': True, '叫': True, '天': True, '赋': True, '和': True, '家': True, '境': True, '一': True, '样': True, '都': True, '是': True, '上': True, '带': True, '来': True, '读': True, '书': True, '破': True, '万': True, '卷': True, '下': True, '笔': True, '如': True, '有': True, '神': True, '不': True, '弹': True, '幕': True, '在': True, '笑': True, '就': True, '学': True, '习': True, '你': True, '决': True, '定': True, '做': True, '要': True, '5': True, '我': True, '们': True, '友': True, '善': True, '点': True, '好': True, '吧': True, '…': True, '把': True, '谁': True, '生': True, '活': True, '铺': True, '开': True, '总': True, '找': True, '质': True, '疑': True, '理': True, '由': True, '朋': True, '6': True, '鬼': True, '泣': True, '瞩': True, '目': True, '劫': True, '期': True, '猛': True, '像': True, '战': True, ' ': True, '虎': True, '后': True, '还': True, '超': True, '级': True, '兵': True, '8': True, '行': True, '出': True, '状': True, '元': True, '啥': True, '面': True, '帅': True, '哥': True, 'C': True, 'R': True, '人': True, '坐': True, '住': True, '~': True, 'w': True, 'c': True, '口': True, '酒': True, '店': True, '怎': True, '熟': True, '悉': True, '他': True, '名': True, '刀': True, '司': True, '命': True, '多': True, '对': True, '同': True, '于': True, '偏': True, '见': True, '接': True, '受': True, '其': True, '挺': True, '小': True, '长': True, '苏': True, '打': True, '张': True, '科': True, '大': True, '佬': True, '脸': True, '无': True, '所': True, '谓': True, '吃': True, '完': True, '春': True, '饭': True, '再': True, '进': True, '厂': True, '也': True, '眼': True, 'J': True, 'K': True, '确': True, '才': True, '阿': True, '金': True, 'N': True, 'O': True, '解': True, '看': True, '吗': True, '何': True, '必': True, '贬': True, '低': True, '电': True, '竞': True, '选': True, '手': True, '久': True, '诚': True, '重': True, '高': True, '中': True, '班': True, '最': True, '居': True, '然': True, '择': True, '职': True, '业': True, '过': True, '纪': True, '单': True, '养': True, '邻': True, '干': True, '白': True, '丝': True, '少': True, '萝': True, '稳': True, '猫': True, '内': True, '肯': True, '牛': True, '逼': True, '屏': True, '黑': True, '双': True, '击': True, '试': True, '复': True, '旦': True, '清': True, '华': True, '专': True, '容': True, '易': True, '本': True, '毕': True, '工': True, '作': True, '现': True, '没': True, '得': True, '各': True, '亚': True, '运': True, '会': True, '代': True, '想': True, '跟': True, '念': True, '@': True, 'm': True, 'E': True, 'S': True, 'Y': True, '网': True, '握': True, '草': True, '姐': True, '太': True, '用': True, '更': True, '呢': True, '压': True, '声': True, '款': True, '校': True, '服': True, '孙': True, '膑': True, '秀': True, '梦': True, '老': True, '师': True, '注': True, '意': True, '叮': True, '～': True, '升': True, '准': True, '备': True, '德': True, '国': True, '修': True, '放': True, '弃': True, '处': True, '转': True, '折': True, '玩': True, '喵': True, '斯': True, '趣': True, '爱': True, '。': True, '坚': True, '持': True, '与': True, '退': True, '缩': True, '差': True, '去': True, '评': True, '判': True, '管': True, '只': True, '挣': True, '那': True, '悔': True, '羡': True, '慕': True, '游': True, '戏': True, '相': True, '通': True, '之': True, '黄': True, '孩': True, '子': True, '以': True, '当': True, '教': True, '练': True, '毛': True, '磊': True, '很':  ...

# %%
import jieba

def read_file(filename):
     stop = [line.strip() for line in  open('/Users/jindie/Desktop/video_2/hit_stopwords_v2.txt','r',encoding='utf-8').readlines()]  #停用词
     f = open(filename,'r',encoding='utf-8')
     line = f.readline()
     str = []
     while line:
         s = line.split('\t')
         fenci = jieba.cut(s[0],cut_all=False)  #False默认值：精准模式
         str.append(list(set(fenci)-set(stop)))
         line = f.readline()
     return str

# %%
from nltk.probability import  FreqDist,ConditionalFreqDist
from nltk.metrics import  BigramAssocMeasures

def jieba_feature(number):   
     posWords = []
     negWords = []
     for items in read_file('/Users/jindie/Desktop/video_2/v2_good.txt'):#把集合的集合变成集合
         for item in items:
            posWords.append(item)
     for items in read_file('/Users/jindie/Desktop/video_2/v2_bad.txt'):
         for item in items:
            negWords.append(item)
  
     word_fd = FreqDist() #可统计所有词的词频
     cond_word_fd = ConditionalFreqDist() #可统计积极文本中的词频和消极文本中的词频
  
     for word in posWords:
         word_fd[word] += 1
         cond_word_fd['pos'][word] += 1
  
     for word in negWords:
         word_fd[word] += 1
         cond_word_fd['neg'][word] += 1
  
     pos_word_count = cond_word_fd['pos'].N() #积极词的数量
     neg_word_count = cond_word_fd['neg'].N() #消极词的数量
     total_word_count = pos_word_count + neg_word_count
  
     word_scores = {}#包括了每个词和这个词的信息量
  
     for word, freq in word_fd.items():
         pos_score = BigramAssocMeasures.chi_sq(cond_word_fd['pos'][word],  (freq, pos_word_count), total_word_count) #计算积极词的卡方统计量，这里也可以计算互信息等其它统计量
         neg_score = BigramAssocMeasures.chi_sq(cond_word_fd['neg'][word],  (freq, neg_word_count), total_word_count) 
         word_scores[word] = pos_score + neg_score #一个词的信息量等于积极卡方统计量加上消极卡方统计量
  
     best_vals = sorted(word_scores.items(), key=lambda item:item[1],  reverse=True)[:number] #把词按信息量倒序排序。number是特征的维度，是可以不断调整直至最优的
     best_words = set([w for w,s in best_vals])
     return dict([(word, True) for word in best_words])

def build_features():
     #feature = bag_of_words(text())#第一种：单个词
     #feature = bigram(text(),score_fn=BigramAssocMeasures.chi_sq,n=500)#第二种：双词
     #feature =  bigram_words(text(),score_fn=BigramAssocMeasures.chi_sq,n=500)#第三种：单个词和双个词
     feature = jieba_feature(300)#第四种：结巴分词
  
     posFeatures = []
     for items in read_file('/Users/jindie/Desktop/video_2/v2_good.txt'):
         a = {}
         for item in items:
            if item in feature.keys():
                a[item]='True'
         posWords = [a,'pos'] #为积极文本赋予"pos"
         posFeatures.append(posWords)
     negFeatures = []
     for items in read_file('/Users/jindie/Desktop/video_2/v2_bad.txt'):
         a = {}
         for item in items:
            if item in feature.keys():
                a[item]='True'
         negWords = [a,'neg'] #为消极文本赋予"neg"
         negFeatures.append(negWords)
     return posFeatures,negFeatures

# %%
posFeatures,negFeatures =  build_features()

from random import shuffle
shuffle(posFeatures) 
shuffle(negFeatures) #把文本的排列随机化  
train =  posFeatures[150:]+negFeatures[150:]#训练集(85%)
test = posFeatures[:150]+negFeatures[:150]#验证集(15%)
data,tag = zip(*test)#分离测试集合的数据和标签，便于验证和测试

def score(classifier):
     classifier = SklearnClassifier(classifier) 
     classifier.train(train) #训练分类器
     pred = classifier.classify_many(data) #给出预测的标签
     n = 0
     s = len(pred)
     for i in range(0,s):
         if pred[i]==tag[i]:
            n = n+1
     return n/s #分类器准确度

import sklearn
from nltk.classify.scikitlearn import  SklearnClassifier
from sklearn.svm import SVC, LinearSVC,  NuSVC
from sklearn.naive_bayes import  MultinomialNB, BernoulliNB
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import  accuracy_score

print('BernoulliNB`s accuracy is %f'  %score(BernoulliNB()))
print('MultinomiaNB`s accuracy is %f'  %score(MultinomialNB()))
print('LogisticRegression`s accuracy is  %f' %score(LogisticRegression()))
print('SVC`s accuracy is %f'  %score(SVC()))
print('LinearSVC`s accuracy is %f'  %score(LinearSVC()))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/sj/13zrkmpd1zsbqqc006p8wmdw0000gn/T/jieba.cache
# Loading model cost 0.334 seconds.
# Prefix dict has been built successfully.
# BernoulliNB`s accuracy is 0.526667
# MultinomiaNB`s accuracy is 0.520000
# LogisticRegression`s accuracy is  0.513333
# SVC`s accuracy is 0.560000
# LinearSVC`s accuracy is 0.533333
# /Users/jindie/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
