# %%
def text():
     f1 = open('/Users/jindie/Desktop/video_4/v4_good.txt','r',encoding='utf-8') 
     f2 = open('/Users/jindie/Desktop/video_4/v4_bad.txt','r',encoding='utf-8')
     line1 = f1.readline()
     line2 = f2.readline()
     str = ''
     while line1:
         str += line1
         line1 = f1.readline()
     while line2:
         str += line2
         line2 = f2.readline()
     f1.close()
     f2.close()
     return str

def bag_of_words(words):
     return dict([(word,True) for word in words])

print(bag_of_words(text()))
# Out:
# {'0': True, '"': True, ':': True, '此': True, '时': True, '的': True, '小': True, '虎': True, '还': True, '没': True, '有': True, '发': True, '现': True, '上': True, '单': True, '才': True, '是': True, '他': True, '归': True, '宿': True, ',': True, '\n': True, '6': True, '因': True, '为': True, '要': True, '和': True, '别': True, '赛': True, '区': True, '打': True, '训': True, '练': True, '，': True, '差': True, '7': True, '这': True, '场': True, '洲': True, '际': True, '硬': True, '币': True, '哥': True, 'M': True, 'V': True, 'P': True, '（': True, '救': True, '世': True, '主': True, '）': True, '8': True, '又': True, '能': True, '看': True, '到': True, '五': True, '个': True, '人': True, '欢': True, '呼': True, '。': True, '真': True, '好': True, '啊': True, '1': True, '2': True, '当': True, '都': True, '知': True, '道': True, '只': True, 'R': True, 'N': True, 'G': True, '就': True, '赢': True, '所': True, '以': True, '最': True, '难': True, '第': True, '四': True, '把': True, '3': True, '说': True, '白': True, '了': True, '两': True, '字': True, '：': True, '天': True, '赋': True, '4': True, '智': True, '慧': True, '眼': True, '神': True, '5': True, '早': True, '游': True, '戏': True, '少': True, '…': True, '比': True, '一': True, '般': True, '下': True, '午': True, '或': True, '晚': True, '开': True, '始': True, '几': True, '乎': True, '国': True, '事': True, '出': True, '更': True, '倒': True, '选': True, '手': True, '奖': True, '杯': True, '渴': True, '望': True, '年': True, '逆': True, '袭': True, '破': True, '釜': True, '沉': True, '舟': True, '背': True, '水': True, '战': True, '忘': True, '不': True, '！': True, '9': True, '初': True, '代': True, '侠': True, '盗': True, 'r': True, 'w': True, '立': True, '大': True, '功': True, 'd': True, 'o': True, 'i': True, 'n': True, 'b': True, '克': True, '烈': True, '王': True, '考': True, '清': True, '华': True, '可': True, '性': True, '万': True, '分': True, '之': True, '但': True, '成': True, '百': True, '电': True, '子': True, '竞': True, '技': True, '菜': True, '原': True, '罪': True, '家': True, '我': True, '们': True, '正': True, '名': True, '荣': True, '耀': True, '再': True, '玩': True, '十': True, '也': True, '会': True, '腻': True, '那': True, '作': True, '息': True, '间': True, '改': True, '朝': True, '九': True, '六': True, '吗': True, '？': True, '身': True, '体': True, '着': True, '想': True, '负': True, '众': True, '熟': True, '悉': True, '面': True, '孔': True, '宁': True, '姿': True, '态': True, '红': True, '色': True, '景': True, '特': True, '传': True, '统': True, '庭': True, '根': True, '苗': True, '捉': True, '肉': True, '鸡': True, 'U': True, ' ': True, 'Z': True, 'I': True, '博': True, '来': True, '走': True, '程': True, '序': True, '某': True, '俱': True, '乐': True, '部': True, '哈': True, '重': True, '点': True, '而': True, 'L': True, '团': True, '结': True, '心': True, '中': True, '月': True, '光': True, '整': True, 'O': True, '支': True, '队': True, '伍': True, '互': True, '相': True, '藏': True, '私': True, '术': True, '什': True, '么': True, '全': True, '共': True, '享': True, '头': True, '脑': True, '风': True, '暴': True, '围': True, '棋': True, '象': True, '样': True, '倾': True, '向': True, '于': True, '类': True, '力': True, '、': True, '意': True, '识': True, '经': True, '验': True, '专': True, '注': True, '拼': True, '连': True, '尊': True, '毫': True, '保': True, '留': True, '话': True, 'l': True, 'p': True, '恐': True, '怖': True, '北': True, '京': True, '豪': True, '门': True, '央': True, '视': True, '给': True, '瘦': True, '脸': True, '你': True, '偶': True, '尔': True, '通': True, '宵': True, '得': True, '?': True, '夺': True, '笋': True, '呐': True, '排': True, '咯': True, '职': True, '业': True, '谁': True, 'T': True, 'h': True, 'e': True, 'S': True, 'y': True, '喜': True, '爸': True, '认': True, '烛': True, '龙': True, '仙': True, '剑': True, '奇': True, '从': True, '后': True, '对': True, '感': True, '兴': True, '趣': True, '金': True, '雨': True, '～': True, '冠': True, '军': True, 'E': True, 'D': True, '牛': True, '逼': True, 'g': True, '班': True, '肯': True, '定': True, '镜': True, '多': True, '且': True, '前': True, '亚': True, '运': True, '去': True, '老': True, '将': True, '死': True, '薪': True, '火': True, '致': True, '敬': True, '羡':  ...

# %%
import nltk
from nltk.collocations import  BigramCollocationFinder
from nltk.metrics import  BigramAssocMeasures

def  bigram(words,score_fn=BigramAssocMeasures.chi_sq,n=1000):
     bigram_finder=BigramCollocationFinder.from_words(words)  #把文本变成双词搭配的形式
     bigrams = bigram_finder.nbest(score_fn,n)  #使用卡方统计的方法，选择排名前1000的双词
     newBigrams = [u+v for (u,v) in bigrams]
     return bag_of_words(newBigrams)
     
print(bigram(text(),score_fn=BigramAssocMeasures.chi_sq,n=1000))
# Out:
# {'*器': True, '\\/': True, '乏味': True, '乒乓': True, '亡列': True, '仁猪': True, '任何': True, '便玷': True, '健康': True, '冷静': True, '凌晨': True, '凝聚': True, '凤凰': True, '刀斯': True, '列车': True, '卡萨': True, '卧槽': True, '原罪': True, '参与': True, '取缔': True, '右边': True, '否适': True, '哽咽': True, '坚持': True, '埋怨': True, '寸断': True, '山鼻': True, '崩溃': True, '巅峰': True, '幕消': True, '建议': True, '弹幕': True, '录片': True, '恐怖': True, '惹嗮': True, '扩*': True, '抱歉': True, '掀翻': True, '新闻': True, '旮旯': True, '朝九': True, '枯燥': True, '沉舟': True, '洗澡': True, '漂亮': True, '漏姓': True, '燥乏': True, '田忌': True, '疙瘩': True, '盈眶': True, '笼包': True, '策划': True, '米勒': True, '羡慕': True, '联盟': True, '肠寸': True, '腱鞘': True, '英雄': True, '茅厕': True, '薪火': True, '藏私': True, '虚弱': True, '虾仁': True, '裹挟': True, '详细': True, '贪图': True, '辉煌': True, '逆袭': True, '透漏': True, '遗憾': True, '采访': True, '釜沉': True, '销户': True, '锻炼': True, '陪男': True, '随便': True, '静集': True, '鞘炎': True, '颈椎': True, '风暴': True, '鼓掌': True, '游戏': True, '牛逼': True, '贵妇': True, '冠军': True, '洲际': True, '排面': True, '荣耀': True, '永远': True, '泪目': True, '硬币': True, '世界': True, '嘻嘻': True, '依旧': True, '北京': True, '容易': True, '残酷': True, 'RN': True, '喜欢': True, '已经': True, '乌兹': True, '修仙': True, '告诉': True, '奥林': True, '归宿': True, '影响': True, '效率': True, '林匹': True, '污渍': True, '熟悉': True, '纪录': True, '规范': True, '篮球': True, 'NG': True, '熬夜': True, '克烈': True, '专注': True, '知道': True, '普通': True, '哈哈': True, '香锅': True, '皮肤': True, '辛苦': True, '戒网': True, '电竞': True, '加油': True, '华班': True, '猝死': True, '肯定': True, '选手': True, '姿态': True, '金色': True, '团结': True, '央视': True, '˙︶': True, '伤病': True, '倾向': True, '偶尔': True, '典型': True, '内卷': True, '划及': True, '刘翔': True, '功劳': True, '勇士': True, '咦～': True, '图安': True, '奋措': True, '女皇': True, '安逸': True, '宝蓝': True, '密达': True, '庆祝': True, '座椅': True, '德培': True, '慢影': True, '挽狂': True, '损害': True, '提倡': True, '收入': True, '智慧': True, '暑假': True, '杀尺': True, '校呗': True, '氛围': True, '浪费': True, '满贯': True, '熊登': True, '版辣': True, '狂澜': True, '环境': True, '男朋': True, '瘦脸': True, '破釜': True, '破防': True, '简称': True, '管它': True, '素质': True, '紧张': True, '紧颈': True, '编剧': True, '美颜': True, '肝肠': True, '苗红': True, '质量': True, '震怒': True, '黑丛': True, '黑暗': True, '鼻祖': True, '︶˙': True, 'ᴗ❛': True, '❛ᴗ': True, '投降': True, '毕竟': True, '离谱': True, '范化': True, '越狠': True, '希望': True, '承诺': True, '无敌': True, '币哥': True, '什么': True, '访苏': True, '网瘾': True, 'ng': True, '自己': True, '可以': True, '亚索': True, '兄弟': True, '朋友': True, '灵性': True, '科奥': True, '舍友': True, '俱乐': True, '努力': True, '训练': True, '职业': True, 'ED': True, '开始': True, '传统': True, '奖杯': True, '青春': True, '作息': True, '者荣': True, '键盘': True, '体育': True, '云霄': True, '份证': True, '保留': True, '印象': True, '哇塞': True, '响彻': True, '培养': True, '声音': True, '奇迹': True, '张状': True, '彻云': True, '怀疑': True, '斯林': True, '星阵': True, '标准': True, '沸腾': True, '玷污': True, '疫情': True, '笋呐': True, '胜负': True, '至臻': True, '舟背': True, '表示': True, '规律': True, '警告': True, '讨厌': True, '证号': True, '象深': True, '负荷': True, '顶级': True, '兴奋': True, '压榨': True, '发麻': True, '吸血': True, '周试': True, '笔记': True, '血鬼': True, '剑魔': True, '夺笋': True, '怀念': True, '易产': True, '致敬': True, '兴趣': True, '验营': True, '~~': True, '侠盗': True, '初代': True, 'rn': True, '读书': True, '阿光': True, '工作': True, '学习': True, '镜头': True, '！！': True, '第五': True, '关键': True, '激动': True, '因为': True, '确实': True, '身体': True, '志豪': True, '星期': True, '老师': True, '天赋': True, '亚运': True, '感觉': True, '=收': True, '京城': True, '充足': True, '击外': True, '劝退': True, '勿喷': True, '化膜': True, '反胃': True, '喘气': True, '外挂': True, '客救': True, '并且': True, '悬念': True, '攻毒': True, '果损': True, '概念': True, '毒攻': True, '清净': True, '清楚': True, '清醒': True, '百万': True, '程序': True, '罗马': True, '财产': True, '资格': True, '踢足': True, '较慢': True, '退籍': True, '退缩': True, '钢化': True, '阵容': True, '靠毒': True, '˙♡': True, '♡˙': True, '二刷': True, '共享': True, '内约': True, '刷野': True, '厉害': True, '及抗': True, '呜呜': True, '围组': True, '娃 ...

# %%
def  bigram_words(words,score_fn=BigramAssocMeasures.chi_sq,n=1000):
     bigram_finder=BigramCollocationFinder.from_words(words)
     bigrams = bigram_finder.nbest(score_fn,n)
     newBigrams = [u+v for (u,v) in bigrams]
     a = bag_of_words(words)
     b = bag_of_words(newBigrams)
     a.update(b)  #把字典b合并到字典a中
     return a 

print(bigram_words(text(),score_fn=BigramAssocMeasures.chi_sq,n=1000))
# Out:
# {'0': True, '"': True, ':': True, '此': True, '时': True, '的': True, '小': True, '虎': True, '还': True, '没': True, '有': True, '发': True, '现': True, '上': True, '单': True, '才': True, '是': True, '他': True, '归': True, '宿': True, ',': True, '\n': True, '6': True, '因': True, '为': True, '要': True, '和': True, '别': True, '赛': True, '区': True, '打': True, '训': True, '练': True, '，': True, '差': True, '7': True, '这': True, '场': True, '洲': True, '际': True, '硬': True, '币': True, '哥': True, 'M': True, 'V': True, 'P': True, '（': True, '救': True, '世': True, '主': True, '）': True, '8': True, '又': True, '能': True, '看': True, '到': True, '五': True, '个': True, '人': True, '欢': True, '呼': True, '。': True, '真': True, '好': True, '啊': True, '1': True, '2': True, '当': True, '都': True, '知': True, '道': True, '只': True, 'R': True, 'N': True, 'G': True, '就': True, '赢': True, '所': True, '以': True, '最': True, '难': True, '第': True, '四': True, '把': True, '3': True, '说': True, '白': True, '了': True, '两': True, '字': True, '：': True, '天': True, '赋': True, '4': True, '智': True, '慧': True, '眼': True, '神': True, '5': True, '早': True, '游': True, '戏': True, '少': True, '…': True, '比': True, '一': True, '般': True, '下': True, '午': True, '或': True, '晚': True, '开': True, '始': True, '几': True, '乎': True, '国': True, '事': True, '出': True, '更': True, '倒': True, '选': True, '手': True, '奖': True, '杯': True, '渴': True, '望': True, '年': True, '逆': True, '袭': True, '破': True, '釜': True, '沉': True, '舟': True, '背': True, '水': True, '战': True, '忘': True, '不': True, '！': True, '9': True, '初': True, '代': True, '侠': True, '盗': True, 'r': True, 'w': True, '立': True, '大': True, '功': True, 'd': True, 'o': True, 'i': True, 'n': True, 'b': True, '克': True, '烈': True, '王': True, '考': True, '清': True, '华': True, '可': True, '性': True, '万': True, '分': True, '之': True, '但': True, '成': True, '百': True, '电': True, '子': True, '竞': True, '技': True, '菜': True, '原': True, '罪': True, '家': True, '我': True, '们': True, '正': True, '名': True, '荣': True, '耀': True, '再': True, '玩': True, '十': True, '也': True, '会': True, '腻': True, '那': True, '作': True, '息': True, '间': True, '改': True, '朝': True, '九': True, '六': True, '吗': True, '？': True, '身': True, '体': True, '着': True, '想': True, '负': True, '众': True, '熟': True, '悉': True, '面': True, '孔': True, '宁': True, '姿': True, '态': True, '红': True, '色': True, '景': True, '特': True, '传': True, '统': True, '庭': True, '根': True, '苗': True, '捉': True, '肉': True, '鸡': True, 'U': True, ' ': True, 'Z': True, 'I': True, '博': True, '来': True, '走': True, '程': True, '序': True, '某': True, '俱': True, '乐': True, '部': True, '哈': True, '重': True, '点': True, '而': True, 'L': True, '团': True, '结': True, '心': True, '中': True, '月': True, '光': True, '整': True, 'O': True, '支': True, '队': True, '伍': True, '互': True, '相': True, '藏': True, '私': True, '术': True, '什': True, '么': True, '全': True, '共': True, '享': True, '头': True, '脑': True, '风': True, '暴': True, '围': True, '棋': True, '象': True, '样': True, '倾': True, '向': True, '于': True, '类': True, '力': True, '、': True, '意': True, '识': True, '经': True, '验': True, '专': True, '注': True, '拼': True, '连': True, '尊': True, '毫': True, '保': True, '留': True, '话': True, 'l': True, 'p': True, '恐': True, '怖': True, '北': True, '京': True, '豪': True, '门': True, '央': True, '视': True, '给': True, '瘦': True, '脸': True, '你': True, '偶': True, '尔': True, '通': True, '宵': True, '得': True, '?': True, '夺': True, '笋': True, '呐': True, '排': True, '咯': True, '职': True, '业': True, '谁': True, 'T': True, 'h': True, 'e': True, 'S': True, 'y': True, '喜': True, '爸': True, '认': True, '烛': True, '龙': True, '仙': True, '剑': True, '奇': True, '从': True, '后': True, '对': True, '感': True, '兴': True, '趣': True, '金': True, '雨': True, '～': True, '冠': True, '军': True, 'E': True, 'D': True, '牛': True, '逼': True, 'g': True, '班': True, '肯': True, '定': True, '镜': True, '多': True, '且': True, '前': True, '亚': True, '运': True, '去': True, '老': True, '将': True, '死': True, '薪': True, '火': True, '致': True, '敬': True, '羡':  ...

# %%
import jieba

def read_file(filename):
     stop = [line.strip() for line in  open('/Users/jindie/Desktop/video_4/hit_stopwords_v4.txt','r',encoding='utf-8').readlines()]  #停用词
     f = open(filename,'r',encoding='utf-8')
     line = f.readline()
     str = []
     while line:
         s = line.split('\t')
         fenci = jieba.cut(s[0],cut_all=False)  #False默认值：精准模式
         str.append(list(set(fenci)-set(stop)))
         line = f.readline()
     return str

# %%
from nltk.probability import  FreqDist,ConditionalFreqDist
from nltk.metrics import  BigramAssocMeasures

def jieba_feature(number):   
     posWords = []
     negWords = []
     for items in read_file('/Users/jindie/Desktop/video_4/v4_good.txt'):#把集合的集合变成集合
         for item in items:
            posWords.append(item)
     for items in read_file('/Users/jindie/Desktop/video_4/v4_bad.txt'):
         for item in items:
            negWords.append(item)
  
     word_fd = FreqDist() #可统计所有词的词频
     cond_word_fd = ConditionalFreqDist() #可统计积极文本中的词频和消极文本中的词频
  
     for word in posWords:
         word_fd[word] += 1
         cond_word_fd['pos'][word] += 1
  
     for word in negWords:
         word_fd[word] += 1
         cond_word_fd['neg'][word] += 1
  
     pos_word_count = cond_word_fd['pos'].N() #积极词的数量
     neg_word_count = cond_word_fd['neg'].N() #消极词的数量
     total_word_count = pos_word_count + neg_word_count
  
     word_scores = {}#包括了每个词和这个词的信息量
  
     for word, freq in word_fd.items():
         pos_score = BigramAssocMeasures.chi_sq(cond_word_fd['pos'][word],  (freq, pos_word_count), total_word_count) #计算积极词的卡方统计量，这里也可以计算互信息等其它统计量
         neg_score = BigramAssocMeasures.chi_sq(cond_word_fd['neg'][word],  (freq, neg_word_count), total_word_count) 
         word_scores[word] = pos_score + neg_score #一个词的信息量等于积极卡方统计量加上消极卡方统计量
  
     best_vals = sorted(word_scores.items(), key=lambda item:item[1],  reverse=True)[:number] #把词按信息量倒序排序。number是特征的维度，是可以不断调整直至最优的
     best_words = set([w for w,s in best_vals])
     return dict([(word, True) for word in best_words])

def build_features():
     #feature = bag_of_words(text())#第一种：单个词
     #feature = bigram(text(),score_fn=BigramAssocMeasures.chi_sq,n=500)#第二种：双词
     #feature =  bigram_words(text(),score_fn=BigramAssocMeasures.chi_sq,n=500)#第三种：单个词和双个词
     feature = jieba_feature(300)#第四种：结巴分词
  
     posFeatures = []
     for items in read_file('/Users/jindie/Desktop/video_4/v4_good.txt'):
         a = {}
         for item in items:
            if item in feature.keys():
                a[item]='True'
         posWords = [a,'pos'] #为积极文本赋予"pos"
         posFeatures.append(posWords)
     negFeatures = []
     for items in read_file('/Users/jindie/Desktop/video_4/v4_bad.txt'):
         a = {}
         for item in items:
            if item in feature.keys():
                a[item]='True'
         negWords = [a,'neg'] #为消极文本赋予"neg"
         negFeatures.append(negWords)
     return posFeatures,negFeatures

# %%
posFeatures,negFeatures =  build_features()

from random import shuffle
shuffle(posFeatures) 
shuffle(negFeatures) #把文本的排列随机化  
train =  posFeatures[100:]+negFeatures[100:]#训练集(90%)
test = posFeatures[:100]+negFeatures[:100]#验证集(90%)
data,tag = zip(*test)#分离测试集合的数据和标签，便于验证和测试

def score(classifier):
     classifier = SklearnClassifier(classifier) 
     classifier.train(train) #训练分类器
     pred = classifier.classify_many(data) #给出预测的标签
     n = 0
     s = len(pred)
     for i in range(0,s):
         if pred[i]==tag[i]:
            n = n+1
     return n/s #分类器准确度

import sklearn
from nltk.classify.scikitlearn import  SklearnClassifier
from sklearn.svm import SVC, LinearSVC,  NuSVC
from sklearn.naive_bayes import  MultinomialNB, BernoulliNB
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import  accuracy_score

print('BernoulliNB`s accuracy is %f'  %score(BernoulliNB()))
print('MultinomiaNB`s accuracy is %f'  %score(MultinomialNB()))
print('LogisticRegression`s accuracy is  %f' %score(LogisticRegression()))
print('SVC`s accuracy is %f'  %score(SVC()))
print('LinearSVC`s accuracy is %f'  %score(LinearSVC()))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/sj/13zrkmpd1zsbqqc006p8wmdw0000gn/T/jieba.cache
# Loading model cost 0.321 seconds.
# Prefix dict has been built successfully.
# BernoulliNB`s accuracy is 0.535000
# MultinomiaNB`s accuracy is 0.525000
# LogisticRegression`s accuracy is  0.505000
# SVC`s accuracy is 0.580000
# LinearSVC`s accuracy is 0.575000
# /Users/jindie/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
